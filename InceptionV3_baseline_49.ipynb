# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
from tensorflow.keras.applications import ResNet152V2
from tensorflow.keras.preprocessing.image import load_img
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
import tensorflow as tf


# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
fid = drive.ListFile({'q':"title='facemo.zip'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('facemo.zip')
f.keys()
# !unzip facemo.zip

# %%
gpus = tf.config.list_logical_devices('GPU') 
stg=tf.distribute.MirroredStrategy(gpus)

# %%
folder_path = "/content/facemo/images/" 
# folder_path = "../input/face-expression-recognition-dataset/images/"
# validation_folder_path = "../input/face-expression-recognition-dataset/images/"

# %%
import cv2
import os
from tqdm import tqdm

folder_dir = '/content/facemo/images/train'
SIZE = 75
DOWNSAMPLE_RATIO = 4
JPEG_QUALITY = 100

# get the total number of files to process
total_files = sum(len(files) for _, _, files in os.walk(folder_dir))

# use tqdm to display a progress bar
with tqdm(total=total_files, desc="Processing Images") as pbar:
    for folder in os.listdir(folder_dir):
        for file in os.listdir(os.path.join(folder_dir, folder)):
            if file.endswith("jpg"):
                image_path = os.path.join(folder_dir, folder, file)
                img = cv2.imread(image_path)
                img_resized = cv2.resize(img, (SIZE,SIZE))
                cv2.imwrite(image_path, img_resized)
                pbar.update(1) # increment the progress bar
            else:
                continue
# Out:
# Processing Images: 100%|██████████| 2827/2827 [00:01<00:00, 2596.75it/s]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
batch_size = 32
picture_size = (SIZE,SIZE)
datagen_train = ImageDataGenerator(rescale=1./255)

datagen_val = ImageDataGenerator(preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input)

train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(folder_path + 'train',
                                                    target_size=(picture_size),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

validation_set = test_datagen.flow_from_directory(folder_path + 'validation',
                                                        target_size=(picture_size),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')
# Out:
# Found 2827 images belonging to 5 classes.
# Found 797 images belonging to 5 classes.

# %%
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.layers.experimental.preprocessing import RandomRotation, RandomTranslation, RandomFlip, RandomZoom
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.optimizers import RMSprop,SGD,Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
from tensorflow.keras.applications import InceptionV3
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt

no_of_classes = 5

with stg.scope():
    img_augmentation = Sequential(
    [
        RandomRotation(factor=0.15),
        RandomTranslation(height_factor=0.1, width_factor=0.1),
        RandomFlip(),
        RandomZoom(height_factor=0.6)
    ],
    name="img_augmentation"
    )

    # Define base model
    base_model = InceptionV3(weights=None, input_shape=(SIZE, SIZE, 3), include_top=False)
    for layer in base_model.layers:
      layer.trainable = True
    # Add image augmentation as the first layer of base model
    inputs = Input(shape=(SIZE, SIZE, 3))
    x = img_augmentation(inputs)
    outputs = base_model(x)

    # Add classification layers on top of the base model
    x = GlobalAveragePooling2D()(outputs)
    x = Dense(512, activation='relu')(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(no_of_classes, activation='softmax')(x)

    # Define the model
    model = Model(inputs=inputs, outputs=predictions)

    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(lr=0.001),
        metrics=['accuracy'])

model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  img_augmentation (Sequentia  (None, 75, 75, 3)        0
#  l)
#
#  inception_v3 (Functional)   (None, 1, 1, 2048)        21802784
#
#  global_average_pooling2d_2   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 512)               1049088
#
#  dense_7 (Dense)             (None, 128)               65664
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 22,918,181
# Trainable params: 22,883,749
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
lr_scheduler = ReduceLROnPlateau(monitor='val_loss',
                                 factor=0.1,
                                 patience=2,
                                 verbose=1)

callbacks = [lr_scheduler]

# %%
history = model.fit(train_generator,
                    steps_per_epoch=train_generator.n // batch_size,
                    epochs=32,
                    validation_data=validation_set,
                    validation_steps=validation_set.n // batch_size,
                    callbacks=callbacks)
# Out:
# Epoch 1/32
# 88/88 [==============================] - 59s 113ms/step - loss: 1.7466 - accuracy: 0.2486 - val_loss: 1.6036 - val_accuracy: 0.2188 - lr: 0.0010
# Epoch 2/32
# 88/88 [==============================] - 10s 118ms/step - loss: 1.5117 - accuracy: 0.3159 - val_loss: 1.5958 - val_accuracy: 0.2669 - lr: 0.0010
# Epoch 3/32
# 88/88 [==============================] - 8s 94ms/step - loss: 1.4302 - accuracy: 0.3939 - val_loss: 1.6188 - val_accuracy: 0.2604 - lr: 0.0010
# Epoch 4/32
# 88/88 [==============================] - ETA: 0s - loss: 1.3632 - accuracy: 0.4347
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 88/88 [==============================] - 8s 85ms/step - loss: 1.3632 - accuracy: 0.4347 - val_loss: 2.0768 - val_accuracy: 0.2930 - lr: 0.0010
# Epoch 5/32
# 88/88 [==============================] - 8s 93ms/step - loss: 1.2214 - accuracy: 0.4937 - val_loss: 1.6796 - val_accuracy: 0.2917 - lr: 1.0000e-04
# Epoch 6/32
# 88/88 [==============================] - 8s 95ms/step - loss: 1.1572 - accuracy: 0.5302 - val_loss: 1.4715 - val_accuracy: 0.4727 - lr: 1.0000e-04
# Epoch 7/32
# 88/88 [==============================] - 8s 90ms/step - loss: 1.1108 - accuracy: 0.5470 - val_loss: 1.1114 - val_accuracy: 0.5482 - lr: 1.0000e-04
# Epoch 8/32
# 88/88 [==============================] - 7s 83ms/step - loss: 1.0986 - accuracy: 0.5660 - val_loss: 1.1411 - val_accuracy: 0.4883 - lr: 1.0000e-04
# Epoch 9/32
# 88/88 [==============================] - ETA: 0s - loss: 1.0768 - accuracy: 0.5635
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 88/88 [==============================] - 7s 84ms/step - loss: 1.0768 - accuracy: 0.5635 - val_loss: 1.1638 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 10/32
# 88/88 [==============================] - 8s 87ms/step - loss: 1.0064 - accuracy: 0.6025 - val_loss: 1.2384 - val_accuracy: 0.4635 - lr: 1.0000e-05
# Epoch 11/32
# 88/88 [==============================] - ETA: 0s - loss: 0.9953 - accuracy: 0.5953
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 88/88 [==============================] - 8s 95ms/step - loss: 0.9953 - accuracy: 0.5953 - val_loss: 1.2582 - val_accuracy: 0.4844 - lr: 1.0000e-05
# Epoch 12/32
# 88/88 [==============================] - 8s 91ms/step - loss: 0.9805 - accuracy: 0.6072 - val_loss: 1.3032 - val_accuracy: 0.4805 - lr: 1.0000e-06
# Epoch 13/32
# 88/88 [==============================] - ETA: 0s - loss: 0.9834 - accuracy: 0.6086
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 88/88 [==============================] - 8s 89ms/step - loss: 0.9834 - accuracy: 0.6086 - val_loss: 1.3072 - val_accuracy: 0.4870 - lr: 1.0000e-06
# Epoch 14/32
# 88/88 [==============================] - 8s 93ms/step - loss: 0.9918 - accuracy: 0.6150 - val_loss: 1.3050 - val_accuracy: 0.4896 - lr: 1.0000e-07
# Epoch 15/32
# 88/88 [==============================] - ETA: 0s - loss: 0.9857 - accuracy: 0.6086
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 88/88 [==============================] - 8s 86ms/step - loss: 0.9857 - accuracy: 0.6086 - val_loss: 1.3228 - val_accuracy: 0.4753 - lr: 1.0000e-07
# Epoch 16/32
# 88/88 [==============================] - 8s 85ms/step - loss: 0.9924 - accuracy: 0.6100 - val_loss: 1.3151 - val_accuracy: 0.4857 - lr: 1.0000e-08
# Epoch 17/32
# 88/88 [==============================] - ETA: 0s - loss: 0.9865 - accuracy: 0.6104
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 88/88 [==============================] - 7s 84ms/step - loss: 0.9865 - accuracy: 0.6104 - val_loss: 1.3199 - val_accuracy: 0.4805 - lr: 1.0000e-08
# Epoch 18/32
# 88/88 [==============================] - 8s 94ms/step - loss: 0.9862 - accuracy: 0.6193 - val_loss: 1.3125 - val_accuracy: 0.4857 - lr: 1.0000e-09
# Epoch 19/32
# 88/88 [==============================] - ETA: 0s - loss: 0.9886 - accuracy: 0.6014
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 88/88 [==============================] - 8s 95ms/step - loss: 0.9886 - accuracy: 0.6014 - val_loss: 1.3218 - val_accuracy: 0.4909 - lr: 1.0000e-09
# Epoch 20/32
# 88/88 [==============================] - 8s 86ms/step - loss: 0.9779 - accuracy: 0.6054 - val_loss: 1.3267 - val_accuracy: 0.4818 - lr: 1.0000e-10
# Epoch 21/32
# 88/88 [==============================] - ETA: 0s - loss: 0.9782 - accuracy: 0.6225
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
# 88/88 [==============================] - 8s 94ms/step - loss: 0.9782 - accuracy: 0.6225 - val_loss: 1.3205 - val_accuracy: 0.4844 - lr: 1.0000e-10
# Epoch 22/32
# 88/88 [==============================] - 8s 94ms/step - loss: 0.9921 - accuracy: 0.6118 - val_loss: 1.3211 - val_accuracy: 0.4609 - lr: 1.0000e-11
# Epoch 23/32
# 88/88 [==============================] - ETA: 0s - loss: 1.0079 - accuracy: 0.5968
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-12.
# 88/88 [==============================] - 7s 84ms/step - loss: 1.0079 - accuracy: 0.5968 - val_loss: 1.3373 - val_accuracy: 0.4883 - lr: 1.0000e-11
# Epoch 24/32
# 88/88 [==============================] - 8s 95ms/step - loss: 0.9796 - accuracy: 0.6147 - val_loss: 1.3213 - val_accuracy: 0.4831 - lr: 1.0000e-12
# Epoch 25/32
# 88/88 [==============================] - ETA: 0s - loss: 1.0286 - accuracy: 0.5875
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000001044244145e-13.
# 88/88 [==============================] - 8s 94ms/step - loss: 1.0286 - accuracy: 0.5875 - val_loss: 1.3411 - val_accuracy: 0.4844 - lr: 1.0000e-12
# Epoch 26/32
# 88/88 [==============================] - 8s 91ms/step - loss: 0.9902 - accuracy: 0.6018 - val_loss: 1.3082 - val_accuracy: 0.4883 - lr: 1.0000e-13
# Epoch 27/32
# 88/88 [==============================] - ETA: 0s - loss: 1.0004 - accuracy: 0.6093
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000001179769417e-14.
# 88/88 [==============================] - 8s 85ms/step - loss: 1.0004 - accuracy: 0.6093 - val_loss: 1.3221 - val_accuracy: 0.4909 - lr: 1.0000e-13
# Epoch 28/32
# 88/88 [==============================] - 7s 84ms/step - loss: 0.9937 - accuracy: 0.6190 - val_loss: 1.3141 - val_accuracy: 0.4883 - lr: 1.0000e-14
# Epoch 29/32
# 88/88 [==============================] - ETA: 0s - loss: 1.0002 - accuracy: 0.6068
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000001518582595e-15.
# 88/88 [==============================] - 8s 94ms/step - loss: 1.0002 - accuracy: 0.6068 - val_loss: 1.3185 - val_accuracy: 0.4857 - lr: 1.0000e-14
# Epoch 30/32
# 88/88 [==============================] - 8s 94ms/step - loss: 0.9707 - accuracy: 0.6036 - val_loss: 1.3192 - val_accuracy: 0.4818 - lr: 1.0000e-15
# Epoch 31/32
# 88/88 [==============================] - ETA: 0s - loss: 0.9787 - accuracy: 0.6025
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000001095066122e-16.
# 88/88 [==============================] - 7s 84ms/step - loss: 0.9787 - accuracy: 0.6025 - val_loss: 1.3227 - val_accuracy: 0.4961 - lr: 1.0000e-15
# Epoch 32/32
# 88/88 [==============================] - 7s 84ms/step - loss: 0.9906 - accuracy: 0.6104 - val_loss: 1.3288 - val_accuracy: 0.5000 - lr: 1.0000e-16

# %%
test_loss, test_acc = model.evaluate(validation_set)
print('Test accuracy:', test_acc)
# Out:
# 25/25 [==============================] - 2s 57ms/step - loss: 1.3307 - accuracy: 0.4956
# Test accuracy: 0.49560853838920593

# %%
import numpy as np
import matplotlib.pyplot as plt
e = ['Angry','Happy','Neutral','Sad','Surprise']
for i in range(len(e)):
    print(i,"=",e[i])
# Get a batch of 10 random images from the test set
test_batch = validation_set.next()
images = test_batch[0][:10]
true_labels = test_batch[1][:10]

# Make predictions using the trained model
pred_probs = model.predict(images)
pred_labels = np.argmax(pred_probs, axis=1)

# Plot the images with their true and predicted labels
fig, axs = plt.subplots(2, 5, figsize=(15, 7))
axs = axs.flatten()

for i in range(len(images)):
    # Rescale the pixel values from [0, 1] to [0, 255] and convert to integers
    img = (images[i] * 255).astype(np.uint8)
    # Invert the pixel values
    axs[i].imshow(img)
    axs[i].set_title(f'True: {true_labels[i]}, Pred: {pred_labels[i]}')
    axs[i].axis('off')

plt.show()
# Out:
# 0 = Angry
# 1 = Happy
# 2 = Neutral
# 3 = Sad
# 4 = Surprise
# 1/1 [==============================] - 2s 2s/step
