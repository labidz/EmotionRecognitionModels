# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
from tensorflow.keras.preprocessing.image import load_img
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, MaxPooling2D
from keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
import tensorflow as tf
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
fid = drive.ListFile({'q':"title='facemo.zip'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('facemo.zip')
f.keys()
# !unzip facemo.zip

# %%
gpus = tf.config.list_logical_devices('GPU') 
stg=tf.distribute.MirroredStrategy(gpus)

# %%
import cv2
import os
from tqdm import tqdm

folder_dir = '/content/facemo/images/train'
SIZE = 75
DOWNSAMPLE_RATIO = 4
JPEG_QUALITY = 100

total_files = sum(len(files) for _, _, files in os.walk(folder_dir))

with tqdm(total=total_files, desc="Processing Images") as pbar:
    for folder in os.listdir(folder_dir):
        for file in os.listdir(os.path.join(folder_dir, folder)):
            if file.endswith("jpg"):
                image_path = os.path.join(folder_dir, folder, file)
                img = cv2.imread(image_path)
                img_resized = cv2.resize(img, (SIZE,SIZE))
                cv2.imwrite(image_path, img_resized)
                pbar.update(1)
            else:
                continue
# Out:
# Processing Images: 100%|██████████| 2827/2827 [00:01<00:00, 2637.97it/s]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
batch_size = 32
picture_size = (75, 75)
train_set = tf.keras.utils.image_dataset_from_directory(
    directory=folder_dir,
    shuffle=True,
    image_size=picture_size,
    batch_size=batch_size,
    label_mode='categorical',
    validation_split=0.2,
    subset='training',
    seed = 22
)

validation_set = tf.keras.utils.image_dataset_from_directory(
    directory=folder_dir,
    shuffle=True,
    image_size=picture_size,
    batch_size=batch_size,
    label_mode='categorical',
    validation_split=0.2,
    subset='validation',
    seed = 22
)
# Out:
# Found 2827 files belonging to 5 classes.
# Using 2262 files for training.
# Found 2827 files belonging to 5 classes.
# Using 565 files for validation.

# %%
from tensorflow.keras.layers import Input, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.layers.experimental.preprocessing import RandomRotation, RandomTranslation, RandomFlip, RandomZoom
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.optimizers import RMSprop,SGD,Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import shutil
import random
import matplotlib.pyplot as plt
from tensorflow.keras.applications import EfficientNetB0

no_of_classes = 5

with stg.scope():
    img_augmentation = Sequential(
    [
        RandomRotation(factor=0.2),
        RandomTranslation(height_factor=0.1, width_factor=0.1),
        RandomZoom(height_factor=0.2)
    ],
    name="img_augmentation"
    )

    base_model = EfficientNetB0(weights="imagenet", input_shape=(SIZE, SIZE, 3), include_top=False)
    inputs = Input(shape=(SIZE, SIZE, 3))
    x = img_augmentation(inputs)
    outputs = base_model(x)

    x = GlobalAveragePooling2D()(outputs)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(32, activation='relu')(x)
    predictions = Dense(no_of_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=predictions)

    model.compile(
        loss='categorical_crossentropy',
        optimizer=Adam(lr=0.001),
        metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_20 (InputLayer)       [(None, 75, 75, 3)]       0
#
#  img_augmentation (Sequentia  (None, 75, 75, 3)        0
#  l)
#
#  efficientnetb0 (Functional)  (None, 3, 3, 1280)       4049571
#
#  global_average_pooling2d_9   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_30 (Dense)            (None, 512)               655872
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_31 (Dense)            (None, 32)                16416
#
#  dense_32 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 4,722,024
# Trainable params: 4,680,001
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
lr_scheduler = ReduceLROnPlateau(monitor='val_loss',
                                 factor=0.1,
                                 patience=2,
                                 verbose=1)
early_stopping = EarlyStopping(monitor='val_loss',
                                patience=5,
                                verbose=1)

callbacks = [lr_scheduler, early_stopping]

# %%
import tensorflow as tf

model.trainable = True

history = model.fit(train_set, epochs=100, validation_data=validation_set, callbacks=callbacks, 
                    steps_per_epoch=len(train_set), validation_steps=len(validation_set))
# Out:
# Epoch 1/100
# 71/71 [==============================] - 58s 117ms/step - loss: 0.8497 - accuracy: 0.6653 - val_loss: 1.3178 - val_accuracy: 0.6956 - lr: 0.0010
# Epoch 2/100
# 71/71 [==============================] - 5s 69ms/step - loss: 0.3916 - accuracy: 0.8634 - val_loss: 0.4231 - val_accuracy: 0.8407 - lr: 0.0010
# Epoch 3/100
# 71/71 [==============================] - 7s 91ms/step - loss: 0.2428 - accuracy: 0.9187 - val_loss: 0.1254 - val_accuracy: 0.9469 - lr: 0.0010
# Epoch 4/100
# 71/71 [==============================] - 5s 69ms/step - loss: 0.2116 - accuracy: 0.9248 - val_loss: 0.1792 - val_accuracy: 0.9469 - lr: 0.0010
# Epoch 5/100
# 71/71 [==============================] - 6s 90ms/step - loss: 0.1635 - accuracy: 0.9483 - val_loss: 0.0781 - val_accuracy: 0.9664 - lr: 0.0010
# Epoch 6/100
# 71/71 [==============================] - 5s 69ms/step - loss: 0.1748 - accuracy: 0.9416 - val_loss: 0.2477 - val_accuracy: 0.9080 - lr: 0.0010
# Epoch 7/100
# 71/71 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9514
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 71/71 [==============================] - 6s 78ms/step - loss: 0.1538 - accuracy: 0.9514 - val_loss: 0.2174 - val_accuracy: 0.9274 - lr: 0.0010
# Epoch 8/100
# 71/71 [==============================] - 5s 70ms/step - loss: 0.0745 - accuracy: 0.9761 - val_loss: 0.0403 - val_accuracy: 0.9912 - lr: 1.0000e-04
# Epoch 9/100
# 71/71 [==============================] - 5s 74ms/step - loss: 0.0429 - accuracy: 0.9881 - val_loss: 0.0267 - val_accuracy: 0.9929 - lr: 1.0000e-04
# Epoch 10/100
# 71/71 [==============================] - 5s 68ms/step - loss: 0.0406 - accuracy: 0.9872 - val_loss: 0.0195 - val_accuracy: 0.9929 - lr: 1.0000e-04
# Epoch 11/100
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0367 - accuracy: 0.9863 - val_loss: 0.0146 - val_accuracy: 0.9947 - lr: 1.0000e-04
# Epoch 12/100
# 71/71 [==============================] - 5s 69ms/step - loss: 0.0408 - accuracy: 0.9863 - val_loss: 0.0181 - val_accuracy: 0.9947 - lr: 1.0000e-04
# Epoch 13/100
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0260 - accuracy: 0.9916 - val_loss: 0.0126 - val_accuracy: 0.9947 - lr: 1.0000e-04
# Epoch 14/100
# 71/71 [==============================] - 5s 70ms/step - loss: 0.0285 - accuracy: 0.9912 - val_loss: 0.0141 - val_accuracy: 0.9947 - lr: 1.0000e-04
# Epoch 15/100
# 71/71 [==============================] - 6s 78ms/step - loss: 0.0275 - accuracy: 0.9920 - val_loss: 0.0038 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 16/100
# 71/71 [==============================] - 5s 69ms/step - loss: 0.0270 - accuracy: 0.9898 - val_loss: 0.0063 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 17/100
# 71/71 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9903
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 71/71 [==============================] - 6s 79ms/step - loss: 0.0295 - accuracy: 0.9903 - val_loss: 0.0057 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 18/100
# 71/71 [==============================] - 5s 70ms/step - loss: 0.0250 - accuracy: 0.9938 - val_loss: 0.0042 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 19/100
# 71/71 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9978
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 71/71 [==============================] - 6s 80ms/step - loss: 0.0099 - accuracy: 0.9978 - val_loss: 0.0038 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 20/100
# 71/71 [==============================] - 5s 68ms/step - loss: 0.0208 - accuracy: 0.9960 - val_loss: 0.0038 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 20: early stopping

# %%
test_loss, test_acc = model.evaluate(validation_set)
print('Test accuracy:', test_acc)
# Out:
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0038 - accuracy: 1.0000
# Test accuracy: 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

e = ['Angry', 'Happy', 'Neutral', 'Sad', 'Surprise']
for i in range(len(e)):
    print(i, "=", e[i])

test_batch = next(iter(validation_set))
images = test_batch[0][:10].numpy()
true_labels = test_batch[1][:10]

pred_probs = model.predict(images)
pred_labels = np.argmax(pred_probs, axis=1)

fig, axs = plt.subplots(2, 5, figsize=(15, 7))
axs = axs.flatten()

for i in range(len(images)):
    img = (images[i] * 255).astype(np.uint8)
    img = 255- img
    axs[i].imshow(img)
    axs[i].set_title(f'True: {true_labels[i]}, Pred: {pred_labels[i]}')
    axs[i].axis('off')

plt.show()
# Out:
# 0 = Angry
# 1 = Happy
# 2 = Neutral
# 3 = Sad
# 4 = Surprise
# 1/1 [==============================] - 2s 2s/step
